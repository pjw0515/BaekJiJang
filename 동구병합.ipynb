# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../gjdata/east201701.csv', encoding='utf-8')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1     지역 측정소명        측정일시   미세먼지  초미세먼지           주소
# 0      384493        384493  광주 동구  서석동  2017010114   54.0   38.0  광주 동구 서남로 1
# 1      384517        384517  광주 동구  서석동  2017010214   66.0   43.0  광주 동구 서남로 1
# 2      384541        384541  광주 동구  서석동  2017010314   74.0   54.0  광주 동구 서남로 1
# 3      384565        384565  광주 동구  서석동  2017010414  127.0   91.0  광주 동구 서남로 1
# 4      384589        384589  광주 동구  서석동  2017010514  104.0   84.0  광주 동구 서남로 1

# %%
df2 = pd.read_csv('../gjdata/east201702.csv', encoding='utf-8')
df2.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1     지역 측정소명        측정일시  미세먼지  초미세먼지           주소
# 0          13        390229  광주 동구  서석동  2017040114   NaN    NaN  광주 동구 서남로 1
# 1          37        390253  광주 동구  서석동  2017040214  53.0   19.0  광주 동구 서남로 1
# 2          61        390277  광주 동구  서석동  2017040314  61.0   38.0  광주 동구 서남로 1
# 3          85        390301  광주 동구  서석동  2017040414  65.0   36.0  광주 동구 서남로 1
# 4         109        390325  광주 동구  서석동  2017040514  30.0    5.0  광주 동구 서남로 1

# %%
df3 = pd.read_csv('../gjdata/east201703.csv', encoding='utf-8')
df3.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1     지역 측정소명        측정일시  미세먼지  초미세먼지           주소
# 0          13        395989  광주 동구  서석동  2017070114  20.0   12.0  광주 동구 서남로 1
# 1          37        396013  광주 동구  서석동  2017070214   3.0    1.0  광주 동구 서남로 1
# 2          61        396037  광주 동구  서석동  2017070314  13.0    5.0  광주 동구 서남로 1
# 3          85        396061  광주 동구  서석동  2017070414   3.0    3.0  광주 동구 서남로 1
# 4         109        396085  광주 동구  서석동  2017070514  27.0   24.0  광주 동구 서남로 1

# %%
df4 = pd.read_csv('../gjdata/east201704.csv', encoding='utf-8')
df4.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1     지역 측정소명        측정일시  미세먼지  초미세먼지           주소
# 0          13        397453  광주 동구  서석동  2017100114  28.0   18.0  광주 동구 서남로 1
# 1          37        397477  광주 동구  서석동  2017100214  17.0   14.0  광주 동구 서남로 1
# 2          61        397501  광주 동구  서석동  2017100314  41.0   17.0  광주 동구 서남로 1
# 3          85        397525  광주 동구  서석동  2017100414  47.0   29.0  광주 동구 서남로 1
# 4         109        397549  광주 동구  서석동  2017100514  22.0   10.0  광주 동구 서남로 1

# %%
result = pd.concat([df,df2,df3,df4])
result
# Out:
#     Unnamed: 0  Unnamed: 0.1     지역 측정소명        측정일시   미세먼지  초미세먼지  \
# 0       384493        384493  광주 동구  서석동  2017010114   54.0   38.0
# 1       384517        384517  광주 동구  서석동  2017010214   66.0   43.0
# 2       384541        384541  광주 동구  서석동  2017010314   74.0   54.0
# 3       384565        384565  광주 동구  서석동  2017010414  127.0   91.0
# 4       384589        384589  광주 동구  서석동  2017010514  104.0   84.0
# 5       384613        384613  광주 동구  서석동  2017010614   16.0    8.0
# 6       384637        384637  광주 동구  서석동  2017010714   51.0   32.0
# 7       384661        384661  광주 동구  서석동  2017010814   22.0    8.0
# 8       384685        384685  광주 동구  서석동  2017010914   33.0   16.0
# 9       384709        384709  광주 동구  서석동  2017011014   29.0    8.0
# 10      384733        384733  광주 동구  서석동  2017011114   18.0    7.0
# 11      384757        384757  광주 동구  서석동  2017011214   40.0   24.0
# 12      384781        384781  광주 동구  서석동  2017011314   47.0   26.0
# ...

# %%
result.to_csv('../gjdata/east201701s.csv', encoding='euc-kr')

# %%
df = pd.read_csv('../dustdata/temp2017.csv', encoding='euc-kr')
df.head()
# Out:
#    Unnamed: 0          일시  최저기온(°C)  최고기온(°C)
# 0           0  2017-01-01      -1.8       5.1
# 1           1  2017-01-02      -1.2       7.6
# 2           2  2017-01-03      -3.5       5.8
# 3           3  2017-01-04      -0.8       4.1
# 4           4  2017-01-05      -0.6       4.6

# %%
df2 = pd.read_csv('../gjdata/east201701s.csv', encoding='euc-kr')
df2.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1     지역 측정소명        측정일시   미세먼지  \
# 0           0        384493          384493  광주 동구  서석동  2017010114   54.0
# 1           1        384517          384517  광주 동구  서석동  2017010214   66.0
# 2           2        384541          384541  광주 동구  서석동  2017010314   74.0
# 3           3        384565          384565  광주 동구  서석동  2017010414  127.0
# 4           4        384589          384589  광주 동구  서석동  2017010514  104.0
#
#    초미세먼지           주소
# 0   38.0  광주 동구 서남로 1
# 1   43.0  광주 동구 서남로 1
# 2   54.0  광주 동구 서남로 1
# 3   91.0  광주 동구 서남로 1
# 4   84.0  광주 동구 서남로 1

# %%
result= pd.concat([df,df2],axis=1)
result
# Out:
#      Unnamed: 0          일시  최저기온(°C)  최고기온(°C)  Unnamed: 0  Unnamed: 0.1  \
# 0           0.0  2017-01-01      -1.8       5.1           0        384493
# 1           1.0  2017-01-02      -1.2       7.6           1        384517
# 2           2.0  2017-01-03      -3.5       5.8           2        384541
# 3           3.0  2017-01-04      -0.8       4.1           3        384565
# 4           4.0  2017-01-05      -0.6       4.6           4        384589
# 5           5.0  2017-01-06      -0.7       8.2           5        384613
# 6           6.0  2017-01-07      -0.5       4.6           6        384637
# 7           7.0  2017-01-08      -0.2       9.0           7        384661
# 8           8.0  2017-01-09      -6.2       0.1           8        384685
# 9           9.0  2017-01-10      -8.1      -0.7           9        384709
# 10         10.0  2017-01-11     -11.9      -3.3          10        384733
# 11         11.0  2017-01-12      -7.2      -0.5          11        384757
# ...

# %%
result.to_csv('../gjdata/tempeast201701.csv', encoding='euc-kr')

# %%
df= pd.read_csv('../gjdata/tempeast201701.csv', sep=',', encoding='euc-kr')

# %%
df
# Out:
#      Unnamed: 0          일시  최저기온(°C)  최고기온(°C)  Unnamed: 0.1  Unnamed: 0.1.1  \
# 0             0  2017-01-01      -1.8       5.1        384493          384493
# 1             1  2017-01-02      -1.2       7.6        384517          384517
# 2             2  2017-01-03      -3.5       5.8        384541          384541
# 3             3  2017-01-04      -0.8       4.1        384565          384565
# 4             4  2017-01-05      -0.6       4.6        384589          384589
# 5             5  2017-01-06      -0.7       8.2        384613          384613
# 6             6  2017-01-07      -0.5       4.6        384637          384637
# 7             7  2017-01-08      -0.2       9.0        384661          384661
# 8             8  2017-01-09      -6.2       0.1        384685          384685
# 9             9  2017-01-10      -8.1      -0.7        384709          384709
# 10           10  2017-01-11     -11.9      -3.3        384733          384733
# ...
