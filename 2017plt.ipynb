# %%
import pandas as pd
import numpy as np
east = pd.read_csv('../2017/east2017.csv', encoding='euc-kr')
south = pd.read_csv('../2017/south2017.csv', encoding='euc-kr')
west_nong = pd.read_csv('../2017/west_nong2017.csv', encoding='euc-kr')
west_chi = pd.read_csv('../2017/west_chi2017.csv', encoding='euc-kr')
north_dooam = pd.read_csv('../2017/north_dooam2017.csv', encoding='euc-kr')
north_unnam = pd.read_csv('../2017/north_unnam2017.csv', encoding='euc-kr')
north_kunkuk = pd.read_csv('../2017/north_kunkuk2017.csv', encoding='euc-kr')
mid_songjeong = pd.read_csv('../2017/mid_songjeong2017.csv', encoding='euc-kr')
mid_oseon = pd.read_csv('../2017/mid_oseon2017.csv', encoding='euc-kr')

# %%
del east['Unnamed: 0']
del east['지역']
del east['측정소명']
del east['주소']
del east['시간']
del south['Unnamed: 0']
del south['지역']
del south['측정소명']
del south['주소']
del south['시간']
del west_nong['Unnamed: 0']
del west_nong['지역']
del west_nong['측정소명']
del west_nong['주소']
del west_nong['시간']
del west_chi['Unnamed: 0']
del west_chi['지역']
del west_chi['측정소명']
del west_chi['주소']
del west_chi['시간']
del north_dooam['Unnamed: 0']
del north_dooam['지역']
del north_dooam['측정소명']
del north_dooam['주소']
del north_dooam['시간']
del north_unnam['Unnamed: 0']
del north_unnam['지역']
del north_unnam['측정소명']
del north_unnam['주소']
del north_unnam['시간']
del north_kunkuk['Unnamed: 0']
del north_kunkuk['지역']
del north_kunkuk['측정소명']
del north_kunkuk['주소']
del north_kunkuk['시간']
del mid_songjeong['Unnamed: 0']
del mid_songjeong['지역']
del mid_songjeong['측정소명']
del mid_songjeong['주소']
del mid_songjeong['시간']
del mid_oseon['Unnamed: 0']
del mid_oseon['지역']
del mid_oseon['측정소명']
del mid_oseon['주소']
del mid_oseon['시간']

# %%
dates = pd.date_range('20160101', periods = 365)

# %%
east.set_index(dates, inplace=True)
south.set_index(dates, inplace=True)
west_nong.set_index(dates, inplace=True)
west_chi.set_index(dates, inplace=True)
north_dooam.set_index(dates, inplace=True)
north_unnam.set_index(dates, inplace=True)
north_kunkuk.set_index(dates, inplace=True)
mid_songjeong.set_index(dates, inplace=True)
mid_oseon.set_index(dates, inplace=True)

# %%
del east ['날짜']
del south ['날짜']
del west_nong['날짜']
del west_chi['날짜']
del north_dooam['날짜']
del north_unnam['날짜']
del north_kunkuk['날짜']
del mid_songjeong['날짜']
del mid_oseon['날짜']

# %%
east.head()
# Out:
#              미세먼지  초미세먼지
# 2016-01-01   54.0   38.0
# 2016-01-02   66.0   43.0
# 2016-01-03   74.0   54.0
# 2016-01-04  127.0   91.0
# 2016-01-05  104.0   84.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

path = "c:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=path).get_name()
rc('font', family=font_name)

# %%
plt.figure(figsize=(12,4))
east.plot()
plt.title("2017년도 광주 동구 미세먼지&초미세먼지")
plt.show()

# %%
plt.figure(figsize=(12,4))
south.plot()
plt.title("2017년도 광주 남구 미세먼지&초미세먼지")
plt.show()

# %%
plt.figure(figsize=(12,4))
west_chi.plot()
plt.title("2017년도 광주 서구 치평동  미세먼지&초미세먼지")
plt.show()

# %%
plt.figure(figsize=(12,4))
west_nong.plot()
plt.title("2017년도 광주 서구 농성동 미세먼지&초미세먼지")
plt.show()

# %%
plt.figure(figsize=(12,4))
mid_oseon.plot()
plt.title("2017년도 광주 광산구 오선동 미세먼지&초미세먼지")
plt.show()

# %%
plt.figure(figsize=(12,4))
mid_songjeong.plot()
plt.title("2017년도 광주 광산구 송정1동 미세먼지&초미세먼지")
plt.show()

# %%
plt.figure(figsize=(12,4))
north_dooam.plot()
plt.title("2017년도 광주 북구 두암동 미세먼지&초미세먼지")
plt.show()

# %%
plt.figure(figsize=(12,4))
north_kunkuk.plot()
plt.title("2017년도 광주 북구 건국동 미세먼지&초미세먼지")
plt.show()

# %%
plt.figure(figsize=(12,4))
north_unnam.plot()
plt.title("2017년도 광주 북구 운암동 미세먼지&초미세먼지")
plt.show()
