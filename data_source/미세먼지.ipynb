# %%
import pandas as pd

# %%
PM_gj = pd.read_csv('../data/미세먼지.csv',encoding='utf-8')
PM_gj.head()
# Out:
#    Unnamed: 0          일시  최저기온(°C)  최고기온(°C)  Unnamed: 0.1  Unnamed: 0.1.1  \
# 0           0  2017-01-01      -1.8       5.1        384493          384493
# 1           1  2017-01-02      -1.2       7.6        384517          384517
# 2           2  2017-01-03      -3.5       5.8        384541          384541
# 3           3  2017-01-04      -0.8       4.1        384565          384565
# 4           4  2017-01-05      -0.6       4.6        384589          384589
#
#       지역 측정소명        측정일시   미세먼지  초미세먼지           주소
# 0  광주 동구  서석동  2017010114   54.0   38.0  광주 동구 서남로 1
# 1  광주 동구  서석동  2017010214   66.0   43.0  광주 동구 서남로 1
# 2  광주 동구  서석동  2017010314   74.0   54.0  광주 동구 서남로 1
# 3  광주 동구  서석동  2017010414  127.0   91.0  광주 동구 서남로 1
# 4  광주 동구  서석동  2017010514  104.0   84.0  광주 동구 서남로 1

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus']=False

if platform.system()=='Darwin':
    rc('font',family=='AppleGothic')
elif platform.system()=='Windows':
    path="c:/Windwos/Fonts/바탕.ttf"
    font_name=font_manager.FontProperties(fname=path).get_name()
    rc('font',family=font_name)
else:
    print('Unknown systme... sorry~~~')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-78-ed48a25667e2> in <module>
#       8 elif platform.system()=='Windows':
#       9     path="c:/Windwos/Fonts/바탕.ttf"
# ---> 10     font_name=font_manager.FontProperties(fname=path).get_name()
#      11     rc('font',family=font_name)
#      12 else:
#
# C:\anaconda\lib\site-packages\matplotlib\font_manager.py in get_name(self)
#     645         Return the name of the font that best matches the font properties.
#     646         """
# --> 647         return get_font(findfont(self)).family_name
#     648
#     649     def get_style(self):
#
# C:\anaconda\lib\site-packages\matplotlib\font_manager.py in get_font(filename, hinting_factor)
#    1289     if hinting_factor is None:
#    1290         hinting_factor = rcParams['text.hinting_factor']
# -> 1291     return _get_font(filename, hinting_factor)
#    1292
# ...

# %%
plt.figure(figsize=(14,10))
plt.scatter(PM_gj['최고기온(°C)'],PM_gj['초미세먼지'],s=50)
plt.plot(x="최고기온(°C)",y="초미세먼지",ls='dashed',lw=3,color='g')

plt.xlabel('최고기온(°C)')
plt.ylabel('미세먼지')

plt.colorbar()
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-e2113e5b7928> in <module>
#       6 plt.ylabel('미세먼지')
#       7
# ----> 8 plt.colorbar()
#       9 plt.grid()
#      10 plt.show()
#
# C:\anaconda\lib\site-packages\matplotlib\pyplot.py in colorbar(mappable, cax, ax, **kw)
#    2098         ax = gca()
#    2099
# -> 2100     ret = gcf().colorbar(mappable, cax = cax, ax=ax, **kw)
#    2101     return ret
#    2102 colorbar.__doc__ = matplotlib.colorbar.colorbar_doc
#
# C:\anaconda\lib\site-packages\matplotlib\figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    2127                              'panchor']
#    2128         cb_kw = {k: v for k, v in kw.items() if k not in NON_COLORBAR_KEYS}
# -> 2129         cb = cbar.colorbar_factory(cax, mappable, **cb_kw)
#    2130
#    2131         self.sca(current_ax)
#
# ...

# %%
plt.figure(figsize=(14,10))
plt.scatter(PM_gj['최고기온(°C)'],PM_gj['미세먼지'],s=50)
plt.plot(x="최고기온(°C)",y="미세먼지",ls='dashed',lw=3,color='g')

plt.xlabel('최고기온(°C)')
plt.ylabel('미세먼지')

plt.colorbar()
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-9334990fced2> in <module>
#       6 plt.ylabel('미세먼지')
#       7
# ----> 8 plt.colorbar()
#       9 plt.grid()
#      10 plt.show()
#
# C:\anaconda\lib\site-packages\matplotlib\pyplot.py in colorbar(mappable, cax, ax, **kw)
#    2098         ax = gca()
#    2099
# -> 2100     ret = gcf().colorbar(mappable, cax = cax, ax=ax, **kw)
#    2101     return ret
#    2102 colorbar.__doc__ = matplotlib.colorbar.colorbar_doc
#
# C:\anaconda\lib\site-packages\matplotlib\figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    2127                              'panchor']
#    2128         cb_kw = {k: v for k, v in kw.items() if k not in NON_COLORBAR_KEYS}
# -> 2129         cb = cbar.colorbar_factory(cax, mappable, **cb_kw)
#    2130
#    2131         self.sca(current_ax)
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set_style("whitegrid")
# %matplotlib inline

# %%
sns.set_style("darkgrid")
sns.lmplot(x="미세먼지",y="초미세먼지",hue="최고기온(°C)",data=PM_gj,palette="Set1",size=20)
plt.show()
# Out:
# C:\anaconda\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(10,6))
plt.plot(x,label='초미세먼지')
plt.plot(y,label='미세먼지')

plt.legend()
plt.show()

# %%
sns.pairplot(PM_gj,vars=["미세먼지","초미세먼지","최고기온(°C)"],kind='reg',size=3)
plot.show()
# Out:
# C:\anaconda\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# C:\anaconda\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\anaconda\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-78123f6b92de> in <module>
#       1 sns.pairplot(PM_gj,vars=["미세먼지","초미세먼지","최고기온(°C)"],kind='reg',size=3)
# ----> 2 plot.show()
#
# NameError: name 'plot' is not defined

# %%
PM_all = pd.read_csv('../data/bubu.csv',encoding='utf-8')
PM_all.head(24)

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="측정일시",y="미세먼지",data=PM_all,palette="Set3")
sns.swarmplot(x="측정일시",y="미세먼지",data=PM_all,color=".6")
plt.show()
