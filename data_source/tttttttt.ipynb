# %%
import pandas as pd
import numpy as np

# %%
dust201701 = pd.read_csv("../data/folder/dust201701.csv", encoding='euc-kr')
dust201702 = pd.read_csv("../data/folder/dust201702.csv", encoding='euc-kr')
dust201703 = pd.read_csv("../data/folder/dust201703.csv", encoding='euc-kr')
dust201704 = pd.read_csv("../data/folder/dust201704.csv", encoding='euc-kr')

# %%
dust201601 = pd.read_csv("../data/folder/dust201601.csv", encoding='euc-kr')
dust201602 = pd.read_csv("../data/folder/dust201602.csv", encoding='euc-kr')
dust201603 = pd.read_csv("../data/folder/dust201603.csv", encoding='euc-kr')
dust201604 = pd.read_csv("../data/folder/dust201604.csv", encoding='euc-kr')

# %%
dust201501 = pd.read_csv("../data/folder/dust201501.csv", encoding='utf-8')
dust201502 = pd.read_csv("../data/folder/dust201502.csv", encoding='utf-8')
dust201503 = pd.read_csv("../data/folder/dust201503.csv", encoding='utf-8')
dust201504 = pd.read_csv("../data/folder/dust201504.csv", encoding='utf-8')

# %%
dust201401 = pd.read_csv("../data/folder/dust201401.csv", encoding='euc-kr')
dust201402 = pd.read_csv("../data/folder/dust201402.csv", encoding='euc-kr')
dust201403 = pd.read_csv("../data/folder/dust201403.csv", encoding='euc-kr')
dust201404 = pd.read_csv("../data/folder/dust201404.csv", encoding='euc-kr')

# %%
dust201301 = pd.read_csv("../data/folder/dust201301.csv", encoding='euc-kr')
dust201302 = pd.read_csv("../data/folder/dust201302.csv", encoding='euc-kr')
dust201303 = pd.read_csv("../data/folder/dust201303.csv", encoding='euc-kr')
dust201304 = pd.read_csv("../data/folder/dust201304.csv", encoding='euc-kr')

# %%
temp1 = pd.concat([dust201701, dust201702])
temp1 = pd.concat([temp1, dust201703])
temp1 = pd.concat([temp1, dust201704])
temp1['시간'] = temp1['측정일시'].astype(str).str.slice(8,10,1)
temp1['날짜'] = temp1['측정일시'].astype(str).str.slice(0,8,1)

# %%
temp2 = pd.concat([dust201601, dust201602])
temp2 = pd.concat([temp2, dust201603])
temp2 = pd.concat([temp2, dust201604])
temp2['시간'] = temp2['측정일시'].astype(str).str.slice(8,10,1)
temp2['날짜'] = temp2['측정일시'].astype(str).str.slice(0,8,1)

# %%
temp3 = pd.concat([dust201501, dust201502])
temp3 = pd.concat([temp3, dust201503])
temp3 = pd.concat([temp3, dust201504])
temp3['시간'] = temp3['측정일시'].astype(str).str.slice(8,10,1)
temp3['날짜'] = temp3['측정일시'].astype(str).str.slice(0,8,1)

# %%
temp4 = pd.concat([dust201401, dust201402])
temp4 = pd.concat([temp4, dust201403])
temp4 = pd.concat([temp4, dust201404])
temp4['시간'] = temp4['측정일시'].astype(str).str.slice(8,10,1)
temp4['날짜'] = temp4['측정일시'].astype(str).str.slice(0,8,1)

# %%
temp5 = pd.concat([dust201301, dust201302])
temp5 = pd.concat([temp5, dust201303])
temp5 = pd.concat([temp5, dust201304])
temp5['시간'] = temp5['측정일시'].astype(str).str.slice(8,10,1)
temp5['날짜'] = temp5['측정일시'].astype(str).str.slice(0,8,1)

# %%
east2017 = temp1[temp1['지역'] == '광주 동구']
east2016 = temp2[temp2['지역'] == '광주 동구']
east2015 = temp3[temp3['지역'] == '광주 동구']
east2014 = temp4[temp4['지역'] == '광주 동구']
east2013 = temp5[temp5['지역'] == '광주 동구']

# %%
east2017 = east2017[east2017['시간'] == '14']
east2016 = east2016[east2016['시간'] == '14']
east2015 = east2015[east2015['시간'] == '14']
east2014 = east2014[east2014['시간'] == '14']
east2013 = east2013[east2013['시간'] == '14']

# %%
cu_weather_2017 = pd.read_csv("../data/chosun2017.csv", encoding='euc-kr')
cu_weather_2016 = pd.read_csv("../data/chosun2016.csv", encoding='euc-kr')
cu_weather_2015 = pd.read_csv("../data/chosun2015.csv", encoding='euc-kr')
cu_weather_2014 = pd.read_csv("../data/chosun2014.csv", encoding='euc-kr')
cu_weather_2013 = pd.read_csv("../data/chosun2013.csv", encoding='euc-kr')

# %%
cu_weather_2017.head()
# Out:
#     지점          일시  평균기온(°C)  일강수량(mm)  평균 풍속(m/s)
# 0  722  2017-01-01       4.1       0.0         1.5
# 1  722  2017-01-02       7.4       0.0         1.3
# 2  722  2017-01-03       5.1       0.0         1.4
# 3  722  2017-01-04       4.3       0.0         1.2
# 4  722  2017-01-05       6.3       0.0         0.9

# %%
dates2017 = pd.date_range('20170101', periods = 365)
dates2016 = pd.date_range('20160101', periods = 366)
dates2015 = pd.date_range('20150101', periods = 365)
dates2014 = pd.date_range('20140101', periods = 365)
dates2013 = pd.date_range('20130101', periods = 365)

# %%
east2017.set_index(dates2017, inplace=True)
east2016.set_index(dates2016, inplace=True)
east2015.set_index(dates2015, inplace=True)
east2014.set_index(dates2014, inplace=True)
east2013.set_index(dates2013, inplace=True)

# %%
cu_weather_2017.set_index(dates2017, inplace=True)
cu_weather_2016.set_index(dates2016, inplace=True)
cu_weather_2015.set_index(dates2015, inplace=True)
cu_weather_2014.set_index(dates2014, inplace=True)
cu_weather_2013.set_index(dates2013, inplace=True)

# %%
concat2017 = pd.concat([east2017, cu_weather_2017], axis=1, join_axes=[east2017.index])
concat2016 = pd.concat([east2016, cu_weather_2016], axis=1, join_axes=[east2016.index])
concat2015 = pd.concat([east2015, cu_weather_2015], axis=1, join_axes=[east2015.index])
concat2014 = pd.concat([east2014, cu_weather_2014], axis=1, join_axes=[east2014.index])
concat2013 = pd.concat([east2013, cu_weather_2013], axis=1, join_axes=[east2013.index])

# %%
concat2015
# Out:
#                지역   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2   PM10  \
# 2015-01-01  광주 동구  324115  서석동  2015010114  0.003  0.5  0.022  0.009   56.0
# 2015-01-02  광주 동구  324115  서석동  2015010214  0.004  0.5  0.013  0.027   19.0
# 2015-01-03  광주 동구  324115  서석동  2015010314  0.003  0.4  0.026  0.014   35.0
# 2015-01-04  광주 동구  324115  서석동  2015010414  0.005  0.8  0.019  0.040   64.0
# 2015-01-05  광주 동구  324115  서석동  2015010514  0.007  1.4  0.006  0.060  111.0
# 2015-01-06  광주 동구  324115  서석동  2015010614  0.002  0.3  0.033  0.012   40.0
# 2015-01-07  광주 동구  324115  서석동  2015010714    NaN  NaN    NaN    NaN   34.0
# 2015-01-08  광주 동구  324115  서석동  2015010814  0.003  0.3  0.029  0.013   35.0
# 2015-01-09  광주 동구  324115  서석동  2015010914  0.010  0.6  0.025  0.023   69.0
# 2015-01-10  광주 동구  324115  서석동  2015011014  0.003  0.3  0.032  0.014   30.0
# 2015-01-11  광주 동구  324115  서석동  2015011114  0.003  0.2  0.033  0.010   24.0
# ...

# %%
over80_2017 = concat2017[concat2017.PM10 > 80]
over80_2016 = concat2016[concat2016.PM10 > 80]
over80_2015 = concat2015[concat2015.PM10 > 80]
over80_2014 = concat2014[concat2014.PM10 > 80]
over80_2013 = concat2013[concat2013.PM10 > 80]

# %%
over80_2013
# Out:
#                지역 측정소명   측정소코드        측정일시    SO2   CO     O3    NO2  PM10  \
# 2013-01-12  광주 동구  서석동  324115  2013011214  0.012  0.9  0.019  0.052    81
# 2013-01-13  광주 동구  서석동  324115  2013011314  0.010  1.6  0.004  0.053    89
# 2013-01-15  광주 동구  서석동  324115  2013011514  0.011  1.3  0.012  0.062    96
# 2013-03-04  광주 동구  서석동  324115  2013030414  0.009  0.7  0.035  0.029    88
# 2013-03-08  광주 동구  서석동  324115  2013030814  0.011  0.7  0.074  0.020   130
# 2013-03-09  광주 동구  서석동  324115  2013030914  0.009  0.5  0.088  0.023   152
# 2013-03-19  광주 동구  서석동  324115  2013031914  0.004  0.8  0.028  0.037   107
# 2013-04-04  광주 동구  서석동  324115  2013040414  0.010  0.8  0.059  0.028    81
# 2013-04-09  광주 동구  서석동  324115  2013040914  0.013  0.4  0.052  0.015   106
# 2013-04-25  광주 동구  서석동  324115  2013042514  0.006  0.9  0.032  0.033    94
# 2013-05-12  광주 동구  서석동  324115  2013051214  0.011  0.7  0.094  0.013   102
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

path = "c:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=path).get_name()
rc('font', family=font_name)

# %%
over80_2017.head()
# Out:
#                지역   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2   PM10  \
# 2017-01-04  광주 동구  324115  서석동  2017010414  0.005  1.0  0.011  0.062  127.0
# 2017-01-05  광주 동구  324115  서석동  2017010514  0.004  0.9  0.015  0.038  104.0
# 2017-01-18  광주 동구  324115  서석동  2017011814  0.007  0.7  0.040  0.020   90.0
# 2017-01-19  광주 동구  324115  서석동  2017011914  0.004  0.7  0.032  0.027  100.0
# 2017-01-26  광주 동구  324115  서석동  2017012614  0.002  0.7  0.017  0.042   84.0
#
#             PM25           주소  시간        날짜   지점          일시  평균기온(°C)  \
# 2017-01-04  91.0  광주 동구 서남로 1  14  20170104  722  2017-01-04       4.3
# 2017-01-05  84.0  광주 동구 서남로 1  14  20170105  722  2017-01-05       6.3
# 2017-01-18  67.0  광주 동구 서남로 1  14  20170118  722  2017-01-18       3.1
# 2017-01-19  82.0  광주 동구 서남로 1  14  20170119  722  2017-01-19       2.1
# 2017-01-26  67.0  광주 동구 서남로 1  14  20170126  722  2017-01-26       0.3
#
#             일강수량(mm)  평균 풍속(m/s)
# 2017-01-04       0.0         1.2
# ...

# %%
tem_des2017 = cu_weather_2017['평균기온(°C)'].describe()
tem_des2016 = cu_weather_2016['평균기온(°C)'].describe()
tem_des2015 = cu_weather_2015['평균기온(°C)'].describe()
tem_des2014 = cu_weather_2014['평균기온(°C)'].describe()
tem_des2013 = cu_weather_2013['평균기온(°C)'].describe()
wind_des2017 = cu_weather_2017['평균 풍속(m/s)'].describe()
wind_des2016 = cu_weather_2016['평균 풍속(m/s)'].describe()
wind_des2015 = cu_weather_2015['평균 풍속(m/s)'].describe()
wind_des2014 = cu_weather_2014['평균 풍속(m/s)'].describe()
wind_des2013 = cu_weather_2013['평균 풍속(m/s)'].describe()

# %%
east_des2017 = east2017['PM10'].describe()
east_des2016 = east2016['PM10'].describe()
east_des2015 = east2015['PM10'].describe()
east_des2014 = east2014['PM10'].describe()
east_des2013 = east2013['PM10'].describe()

# %%
tem_des2017
# Out:
# count    365.000000
# mean      14.178904
# std        9.507841
# min       -3.700000
# 25%        5.500000
# 50%       15.500000
# 75%       22.400000
# max       29.900000
# Name: 평균기온(°C), dtype: float64

# %%
plt.figure(figsize=(6,6))
plt.scatter(over80_2017['평균기온(°C)'],over80_2017['PM10'], s = 50)
plt.grid()
plt.xlabel('평균기온(°C)')
plt.ylabel('미세먼지')
plt.title('2017년 동구')
plt.show()

# %%
wea_des2016
# Out:
# count    366.000000
# mean      14.709290
# std        9.326429
# min       -9.400000
# 25%        6.500000
# 50%       15.700000
# 75%       22.400000
# max       29.700000
# Name: 평균기온(°C), dtype: float64

# %%
plt.figure(figsize=(6,6))
plt.scatter(over80_2016['평균기온(°C)'],over80_2016['PM10'], s = 50)
plt.grid()
plt.xlabel('평균기온(°C)')
plt.ylabel('미세먼지')
plt.title('2016년 동구')
plt.show()

# %%
wea_des2015
# Out:
# count    365.000000
# mean      14.321918
# std        8.607868
# min       -4.100000
# 25%        6.000000
# 50%       15.700000
# 75%       21.700000
# max       29.300000
# Name: 평균기온(°C), dtype: float64

# %%
plt.figure(figsize=(6,6))
plt.scatter(over80_2015['평균기온(°C)'],over80_2015['PM10'], s = 50)
plt.grid()
plt.xlabel('평균기온(°C)')
plt.ylabel('미세먼지')
plt.title('2015년 동구')
plt.show()

# %%
wea_des2014
# Out:
# count    363.000000
# mean      13.869421
# std        8.790212
# min       -4.700000
# 25%        5.850000
# 50%       14.700000
# 75%       22.000000
# max       29.100000
# Name: 평균기온(°C), dtype: float64

# %%
plt.figure(figsize=(6,6))
plt.scatter(over80_2014['평균기온(°C)'],over80_2014['PM10'], s = 50)
plt.grid()
plt.xlabel('평균기온(°C)')
plt.ylabel('미세먼지')
plt.title('2014년 동구')
plt.show()

# %%
wea_des2013
# Out:
# count    365.000000
# mean      13.884932
# std       10.042151
# min       -6.700000
# 25%        4.900000
# 50%       14.100000
# 75%       23.200000
# max       30.200000
# Name: 평균기온(°C), dtype: float64

# %%
plt.figure(figsize=(6,6))
plt.scatter(over80_2013['평균기온(°C)'],over80_2013['PM10'], s = 50)
plt.grid()
plt.xlabel('평균기온(°C)')
plt.ylabel('미세먼지')
plt.title('2013년 동구')
plt.show()
