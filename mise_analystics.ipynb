# %%
import pandas as pd
import numpy as np

# %%
east2017 = pd.read_csv("../data/data_source/data2017/east2017.csv", encoding='euc-kr')
west2017 = pd.read_csv("../data/data_source/data2017/west2017.csv", encoding='euc-kr')
south2017 = pd.read_csv("../data/data_source/data2017/south2017.csv", encoding='euc-kr')
north2017 = pd.read_csv("../data/data_source/data2017/north2017.csv", encoding='euc-kr')
md2017 = pd.read_csv("../data/data_source/data2017/md2017.csv", encoding='euc-kr')
gist2017 = pd.read_csv("../data/data_source/gist2017.csv", encoding='euc-kr')
mid2017 = pd.read_csv("../data/data_source/mid2017.csv", encoding='euc-kr')
cu2017 = pd.read_csv("../data/data_source/cu2017.csv", encoding='euc-kr')
seogu2017 = pd.read_csv("../data/data_source/seogu2017.csv", encoding='euc-kr')

# %%
east2017.head()
# Out:
#    Unnamed: 0     지역        측정일시   미세먼지  초미세먼지
# 0           0  광주 동구  2017010114   54.0   38.0
# 1           1  광주 동구  2017010214   66.0   43.0
# 2           2  광주 동구  2017010314   74.0   54.0
# 3           3  광주 동구  2017010414  127.0   91.0
# 4           4  광주 동구  2017010514  104.0   84.0

# %%
west2017.head()
# Out:
#    Unnamed: 0     지역        측정일시   미세먼지  초미세먼지
# 0           0  광주 서구  2017010114   50.0    NaN
# 1           1  광주 서구  2017010214   62.0    NaN
# 2           2  광주 서구  2017010314   81.0    NaN
# 3           3  광주 서구  2017010414  111.0    NaN
# 4           4  광주 서구  2017010514  101.0    NaN

# %%
del east2017['Unnamed: 0']
del east2017['지역']
del east2017['측정일시']
del west2017['Unnamed: 0']
del west2017['지역']
del west2017['측정일시']
del south2017['Unnamed: 0']
del south2017['지역']
del south2017['측정일시']
del north2017['Unnamed: 0']
del north2017['지역']
del north2017['측정일시']
del md2017['Unnamed: 0']
del md2017['지역']
del md2017['측정일시']

# %%
east2017.head()
# Out:
#     미세먼지  초미세먼지
# 0   54.0   38.0
# 1   66.0   43.0
# 2   74.0   54.0
# 3  127.0   91.0
# 4  104.0   84.0

# %%
gist2017.head()
# Out:
#     지점          일시  평균기온(°C)  평균 풍속(m/s)
# 0  708  2017-01-01       2.4         0.8
# 1  708  2017-01-02       6.0         1.1
# 2  708  2017-01-03       4.7         1.6
# 3  708  2017-01-04       3.4         1.1
# 4  708  2017-01-05       5.6         1.0

# %%
del gist2017['지점']
del gist2017['일시']
del cu2017['지점']
del cu2017['일시']
del mid2017['지점']
del mid2017['일시']
del seogu2017['지점']
del seogu2017['일시']

# %%
gist2017.head()
# Out:
#    평균기온(°C)  평균 풍속(m/s)
# 0       2.4         0.8
# 1       6.0         1.1
# 2       4.7         1.6
# 3       3.4         1.1
# 4       5.6         1.0

# %%
gist2017_temperature = pd.DataFrame(gist2017['평균기온(°C)'])
gist2017_windspeed = pd.DataFrame(gist2017['평균 풍속(m/s)'])
cu2017_temperature = pd.DataFrame(cu2017['평균기온(°C)'])
cu2017_windspeed = pd.DataFrame(cu2017['평균 풍속(m/s)'])
mid2017_temperature = pd.DataFrame(mid2017['평균기온(°C)'])
mid2017_windspeed = pd.DataFrame(mid2017['평균 풍속(m/s)'])
seogu2017_temperature = pd.DataFrame(seogu2017['평균기온(°C)'])
seogu2017_windspeed = pd.DataFrame(seogu2017['평균 풍속(m/s)'])

# %%
gist2017_temperature.head()
# Out:
#    평균기온(°C)
# 0       2.4
# 1       6.0
# 2       4.7
# 3       3.4
# 4       5.6

# %%
gist2017_windspeed.head()
# Out:
#    평균 풍속(m/s)
# 0         0.8
# 1         1.1
# 2         1.6
# 3         1.1
# 4         1.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus']=False

path="C:\Windows\Fonts\HMKMMAG.ttf"
font_name=font_manager.FontProperties(fname=path).get_name()
rc('font',family=font_name)

# %%
plt.figure(figsize=(15,5))
plt.title("2017년 광주 동구 미세먼지&초미세먼지 측정")
plt.grid()
plt.plot(east2017)
plt.xlabel('측정일자')
plt.ylabel('농도')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title("2017년 광주 동구(조선대) 평균기온 측정")
plt.plot(cu2017_temperature)
plt.xlabel('측정일자')
plt.ylabel('기온')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title("2017년 광주 동구(조선대) 평균풍속 측정")
plt.plot(cu2017_windspeed)
plt.xlabel('측정일자')
plt.ylabel('풍속')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title("2017년 광주 서구 미세먼지&초미세먼지 측정")
plt.grid()
plt.plot(west2017)
plt.xlabel('측정일자')
plt.ylabel('농도')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title("2017년 광주 서구(풍암동) 평균기온 측정")
plt.plot(seogu2017_temperature)
plt.xlabel('측정일자')
plt.ylabel('기온')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title("2017년 광주 서구(풍암동) 평균풍속 측정")
plt.plot(seogu2017_windspeed)
plt.xlabel('측정일자')
plt.ylabel('풍속')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title("2017년 광주 북구 미세먼지&초미세먼지 측정")
plt.grid()
plt.plot(north2017)
plt.xlabel('측정일자')
plt.ylabel('농도')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title("2017년 광주 북구(GIST) 평균기온 측정")
plt.plot(gist2017_temperature)
plt.xlabel('측정일자')
plt.ylabel('기온')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title("2017년 광주 북구(GIST) 평균풍속 측정")
plt.plot(gist2017_windspeed)
plt.xlabel('측정일자')
plt.ylabel('풍속')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title("2017년 광주 광산구 미세먼지&초미세먼지 측정")
plt.grid()
plt.plot(md2017)
plt.xlabel('측정일자')
plt.ylabel('농도')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title("2017년 광주 광산구(농업기술센터) 평균기온 측정")
plt.plot(mid2017_temperature)
plt.xlabel('측정일자')
plt.ylabel('기온')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title("2017년 광주 광산구(농업기술센터) 평균풍속 측정")
plt.plot(mid2017_windspeed)
plt.xlabel('측정일자')
plt.ylabel('풍속')
plt.grid()
plt.show()
