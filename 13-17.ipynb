# %%
import pandas as pd
import numpy as np

# %%
dust201601 = pd.read_csv("../dustdata/gj201601.csv", encoding='euc-kr')
dust201602 = pd.read_csv("../dustdata/gj201602.csv", encoding='euc-kr')
dust201603 = pd.read_csv("../dustdata/gj201603.csv", encoding='euc-kr')
dust201604 = pd.read_csv("../dustdata/gj201604.csv", encoding='euc-kr')

# %%
temp = pd.concat([dust201601, dust201602])
temp = pd.concat([temp, dust201603])
temp = pd.concat([temp, dust201604])

# %%
temp['시간'] = temp['측정일시'].astype(str).str.slice(8,10,1)
temp['날짜'] = temp['측정일시'].astype(str).str.slice(0,8,1)
temp.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1      지역  측정소명        측정일시  미세먼지  초미세먼지  \
# 0      290472        290472  광주 광산구  송정1동  2016010101  62.0   41.0
# 1      290473        290473  광주 광산구  송정1동  2016010102  61.0   43.0
# 2      290474        290474  광주 광산구  송정1동  2016010103  64.0   46.0
# 3      290475        290475  광주 광산구  송정1동  2016010104  60.0   42.0
# 4      290476        290476  광주 광산구  송정1동  2016010105  56.0   42.0
#
#               주소  시간        날짜
# 0  광주 광산구 광산로 70  01  20160101
# 1  광주 광산구 광산로 70  02  20160101
# 2  광주 광산구 광산로 70  03  20160101
# 3  광주 광산구 광산로 70  04  20160101
# 4  광주 광산구 광산로 70  05  20160101

# %%
del temp['Unnamed: 0']
del temp['Unnamed: 0.1']
del temp['측정일시']

# %%
east = temp[temp['지역'] == '광주 동구']
west = temp[temp['지역'] == '광주 서구']
south = temp[temp['지역'] == '광주 남구']
north = temp[temp['지역'] == '광주 북구']
mid = temp[temp['지역'] == '광주 광산구']
west_nong = west[west['측정소명'] == '농성동']
west_chi = west[west['측정소명'] == '치평동']
north_dooam = north[north['측정소명'] == '두암동']
north_unnam = north[north['측정소명'] == '운암동']
north_kunkuk = north[north['측정소명'] == '건국동']
mid_songjeong = mid[mid['측정소명'] == '송정1동']
mid_oseon = mid[mid['측정소명'] == '오선동']

# %%
east = east[east['시간'] == '14']
south = south[south['시간'] == '14']
west_nong = west_nong[west_nong['시간'] == '14']
west_chi = west_chi[west_chi['시간'] == '14']
north_dooam = north_dooam[north_dooam['시간'] == '14']
north_unnam = north_unnam[north_unnam['시간'] == '14']
north_kunkuk = north_kunkuk[north_kunkuk['시간'] == '14']
mid_songjeong = mid_songjeong[mid_songjeong['시간'] == '14']
mid_oseon = mid_oseon[mid_oseon['시간'] == '14']

# %%
east.to_csv('../dust2016/east2016.csv', encoding='euc-kr')
south.to_csv('../dust2016/south2016.csv', encoding='euc-kr')
west_nong.to_csv('../dust2016/west_nong2016.csv', encoding='euc-kr')
west_chi.to_csv('../dust2016/west_chi2016.csv', encoding='euc-kr')
north_dooam.to_csv('../dust2016/north_dooam2016.csv', encoding='euc-kr')
north_unnam.to_csv('../dust2016/north_unnam2016.csv', encoding='euc-kr')
north_kunkuk.to_csv('../dust2016/north_kunkuk2016.csv', encoding='euc-kr')
mid_songjeong.to_csv('../dust2016/mid_songjeong2016.csv', encoding='euc-kr')
mid_oseon.to_csv('../dust2016/mid_oseon2016.csv', encoding='euc-kr')

# %%
dust201501 = pd.read_csv("../dustdata/gj201501.csv", encoding='euc-kr')
dust201502 = pd.read_csv("../dustdata/gj201502.csv", encoding='euc-kr')
dust201503 = pd.read_csv("../dustdata/gj201503.csv", encoding='euc-kr')
dust201504 = pd.read_csv("../dustdata/gj201504.csv", encoding='euc-kr')

# %%
temp = pd.concat([dust201501, dust201502])
temp = pd.concat([temp, dust201503])
temp = pd.concat([temp, dust201504])

# %%
temp['시간'] = temp['측정일시'].astype(str).str.slice(8,10,1)
temp['날짜'] = temp['측정일시'].astype(str).str.slice(0,8,1)
temp.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1      지역  측정소명        측정일시  미세먼지  초미세먼지  \
# 0      285864        285864  광주 광산구  송정1동  2015010101  10.0    9.0
# 1      285865        285865  광주 광산구  송정1동  2015010102  17.0    9.0
# 2      285866        285866  광주 광산구  송정1동  2015010103   8.0    1.0
# 3      285867        285867  광주 광산구  송정1동  2015010104   6.0    3.0
# 4      285868        285868  광주 광산구  송정1동  2015010105   7.0    2.0
#
#               주소  시간        날짜
# 0  광주 광산구 광산로 70  01  20150101
# 1  광주 광산구 광산로 70  02  20150101
# 2  광주 광산구 광산로 70  03  20150101
# 3  광주 광산구 광산로 70  04  20150101
# 4  광주 광산구 광산로 70  05  20150101

# %%
del temp['Unnamed: 0']
del temp['Unnamed: 0.1']
del temp['측정일시']

# %%
east = temp[temp['지역'] == '광주 동구']
west = temp[temp['지역'] == '광주 서구']
south = temp[temp['지역'] == '광주 남구']
north = temp[temp['지역'] == '광주 북구']
mid = temp[temp['지역'] == '광주 광산구']
west_nong = west[west['측정소명'] == '농성동']
west_chi = west[west['측정소명'] == '치평동']
north_dooam = north[north['측정소명'] == '두암동']
north_unnam = north[north['측정소명'] == '운암동']
north_kunkuk = north[north['측정소명'] == '건국동']
mid_songjeong = mid[mid['측정소명'] == '송정1동']
mid_oseon = mid[mid['측정소명'] == '오선동']

# %%
east = east[east['시간'] == '14']
south = south[south['시간'] == '14']
west_nong = west_nong[west_nong['시간'] == '14']
west_chi = west_chi[west_chi['시간'] == '14']
north_dooam = north_dooam[north_dooam['시간'] == '14']
north_unnam = north_unnam[north_unnam['시간'] == '14']
north_kunkuk = north_kunkuk[north_kunkuk['시간'] == '14']
mid_songjeong = mid_songjeong[mid_songjeong['시간'] == '14']
mid_oseon = mid_oseon[mid_oseon['시간'] == '14']

# %%
east.to_csv('../dust2015/east2015.csv', encoding='euc-kr')
south.to_csv('../dust2015/south2015.csv', encoding='euc-kr')
west_nong.to_csv('../dust2015/west_nong2015.csv', encoding='euc-kr')
west_chi.to_csv('../dust2015/west_chi2015.csv', encoding='euc-kr')
north_dooam.to_csv('../dust2015/north_dooam2015.csv', encoding='euc-kr')
north_unnam.to_csv('../dust2015/north_unnam2015.csv', encoding='euc-kr')
north_kunkuk.to_csv('../dust2015/north_kunkuk2015.csv', encoding='euc-kr')
mid_songjeong.to_csv('../dust2015/mid_songjeong2015.csv', encoding='euc-kr')
mid_oseon.to_csv('../dust2015/mid_oseon2015.csv', encoding='euc-kr')

# %%
dust201401 = pd.read_csv("../dustdata/gj201401.csv", encoding='euc-kr')
dust201402 = pd.read_csv("../dustdata/gj201402.csv", encoding='euc-kr')
dust201403 = pd.read_csv("../dustdata/gj201403.csv", encoding='euc-kr')
dust201404 = pd.read_csv("../dustdata/gj201404.csv", encoding='euc-kr')

# %%
temp = pd.concat([dust201401, dust201402])
temp = pd.concat([temp, dust201403])
temp = pd.concat([temp, dust201404])

# %%
temp['시간'] = temp['측정일시'].astype(str).str.slice(8,10,1)
temp['날짜'] = temp['측정일시'].astype(str).str.slice(0,8,1)
temp.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1      지역  측정소명        측정일시   미세먼지  초미세먼지  \
# 0      285120        285120  광주 광산구  송정1동  2014010101  128.0    NaN
# 1      285121        285121  광주 광산구  송정1동  2014010102  123.0    NaN
# 2      285122        285122  광주 광산구  송정1동  2014010103  130.0    NaN
# 3      285123        285123  광주 광산구  송정1동  2014010104  129.0    NaN
# 4      285124        285124  광주 광산구  송정1동  2014010105  139.0    NaN
#
#               주소  시간        날짜
# 0  광주 광산구 광산로 70  01  20140101
# 1  광주 광산구 광산로 70  02  20140101
# 2  광주 광산구 광산로 70  03  20140101
# 3  광주 광산구 광산로 70  04  20140101
# 4  광주 광산구 광산로 70  05  20140101

# %%
del temp['Unnamed: 0']
del temp['Unnamed: 0.1']
del temp['측정일시']

# %%
east = temp[temp['지역'] == '광주 동구']
west = temp[temp['지역'] == '광주 서구']
south = temp[temp['지역'] == '광주 남구']
north = temp[temp['지역'] == '광주 북구']
mid = temp[temp['지역'] == '광주 광산구']
west_nong = west[west['측정소명'] == '농성동']
west_chi = west[west['측정소명'] == '치평동']
north_dooam = north[north['측정소명'] == '두암동']
north_unnam = north[north['측정소명'] == '운암동']
north_kunkuk = north[north['측정소명'] == '건국동']
mid_songjeong = mid[mid['측정소명'] == '송정1동']
mid_oseon = mid[mid['측정소명'] == '오선동']

# %%
east = east[east['시간'] == '14']
south = south[south['시간'] == '14']
west_nong = west_nong[west_nong['시간'] == '14']
west_chi = west_chi[west_chi['시간'] == '14']
north_dooam = north_dooam[north_dooam['시간'] == '14']
north_unnam = north_unnam[north_unnam['시간'] == '14']
north_kunkuk = north_kunkuk[north_kunkuk['시간'] == '14']
mid_songjeong = mid_songjeong[mid_songjeong['시간'] == '14']
mid_oseon = mid_oseon[mid_oseon['시간'] == '14']

# %%
east.to_csv('../dust2014/east2014.csv', encoding='euc-kr')
south.to_csv('../dust2014/south2014.csv', encoding='euc-kr')
west_nong.to_csv('../dust2014/west_nong2014.csv', encoding='euc-kr')
west_chi.to_csv('../dust2014/west_chi2014.csv', encoding='euc-kr')
north_dooam.to_csv('../dust2014/north_dooam2014.csv', encoding='euc-kr')
north_unnam.to_csv('../dust2014/north_unnam2014.csv', encoding='euc-kr')
north_kunkuk.to_csv('../dust2014/north_kunkuk2014.csv', encoding='euc-kr')
mid_songjeong.to_csv('../dust2014/mid_songjeong2014.csv', encoding='euc-kr')
mid_oseon.to_csv('../dust2014/mid_oseon2014.csv', encoding='euc-kr')

# %%
dust201301 = pd.read_csv("../dustdata/gj201301.csv", encoding='euc-kr')
dust201302 = pd.read_csv("../dustdata/gj201302.csv", encoding='euc-kr')
dust201303 = pd.read_csv("../dustdata/gj201303.csv", encoding='euc-kr')
dust201304 = pd.read_csv("../dustdata/gj201304.csv", encoding='euc-kr')

# %%
temp = pd.concat([dust201301, dust201302])
temp = pd.concat([temp, dust201303])
temp = pd.concat([temp, dust201304])

# %%
temp['시간'] = temp['측정일시'].astype(str).str.slice(8,10,1)
temp['날짜'] = temp['측정일시'].astype(str).str.slice(0,8,1)
temp.head()
# Out:
#   Unnamed: 0     지역 측정소명        측정일시 PM10            주소  시간        날짜
# 0     379416  광주 동구  서석동  2013010101   13  광주 동구 서석동 31  01  20130101
# 1     379417  광주 동구  서석동  2013010102   13  광주 동구 서석동 31  02  20130101
# 2     379418  광주 동구  서석동  2013010103   14  광주 동구 서석동 31  03  20130101
# 3     379419  광주 동구  서석동  2013010104   13  광주 동구 서석동 31  04  20130101
# 4     379420  광주 동구  서석동  2013010105   15  광주 동구 서석동 31  05  20130101

# %%
del temp['Unnamed: 0']
del temp['측정일시']

# %%
east = temp[temp['지역'] == '광주 동구']
west = temp[temp['지역'] == '광주 서구']
south = temp[temp['지역'] == '광주 남구']
north = temp[temp['지역'] == '광주 북구']
mid = temp[temp['지역'] == '광주 광산구']
west_nong = west[west['측정소명'] == '농성동']
west_chi = west[west['측정소명'] == '치평동']
north_dooam = north[north['측정소명'] == '두암동']
north_unnam = north[north['측정소명'] == '운암동']
north_kunkuk = north[north['측정소명'] == '건국동']
mid_songjeong = mid[mid['측정소명'] == '송정1동']
mid_oseon = mid[mid['측정소명'] == '오선동']

# %%
east = east[east['시간'] == '14']
south = south[south['시간'] == '14']
west_nong = west_nong[west_nong['시간'] == '14']
west_chi = west_chi[west_chi['시간'] == '14']
north_dooam = north_dooam[north_dooam['시간'] == '14']
north_unnam = north_unnam[north_unnam['시간'] == '14']
north_kunkuk = north_kunkuk[north_kunkuk['시간'] == '14']
mid_songjeong = mid_songjeong[mid_songjeong['시간'] == '14']
mid_oseon = mid_oseon[mid_oseon['시간'] == '14']

# %%
east.rename(columns = {'PM10': '미세먼지', 'PM25': '초미세먼지'}, inplace=True)
south.rename(columns = {'PM10': '미세먼지', 'PM25': '초미세먼지'}, inplace=True)
west_nong.rename(columns = {'PM10': '미세먼지', 'PM25': '초미세먼지'}, inplace=True)
west_chi.rename(columns = {'PM10': '미세먼지', 'PM25': '초미세먼지'}, inplace=True)
north_dooam.rename(columns = {'PM10': '미세먼지', 'PM25': '초미세먼지'}, inplace=True)
north_unnam.rename(columns = {'PM10': '미세먼지', 'PM25': '초미세먼지'}, inplace=True)
north_kunkuk.rename(columns = {'PM10': '미세먼지', 'PM25': '초미세먼지'}, inplace=True)
mid_songjeong.rename(columns = {'PM10': '미세먼지', 'PM25': '초미세먼지'}, inplace=True)
mid_oseon.rename(columns = {'PM10': '미세먼지', 'PM25': '초미세먼지'}, inplace=True)

# %%
east.to_csv('../dust2013/east2013.csv', encoding='euc-kr')
south.to_csv('../dust2013/south2013.csv', encoding='euc-kr')
west_nong.to_csv('../dust2013/west_nong2013.csv', encoding='euc-kr')
west_chi.to_csv('../dust2013/west_chi2013.csv', encoding='euc-kr')
north_dooam.to_csv('../dust2013/north_dooam2013.csv', encoding='euc-kr')
north_unnam.to_csv('../dust2013/north_unnam2013.csv', encoding='euc-kr')
north_kunkuk.to_csv('../dust2013/north_kunkuk2013.csv', encoding='euc-kr')
mid_songjeong.to_csv('../dust2013/mid_songjeong2013.csv', encoding='euc-kr')
mid_oseon.to_csv('../dust2013/mid_oseon2013.csv', encoding='euc-kr')

# %%
dust201701 = pd.read_csv("../dustdata/gj201701.csv", encoding='euc-kr')
dust201702 = pd.read_csv("../dustdata/gj201702.csv", encoding='euc-kr')
dust201703 = pd.read_csv("../dustdata/gj201703.csv", encoding='euc-kr')
dust201704 = pd.read_csv("../dustdata/gj201704.csv", encoding='euc-kr')

# %%
temp = pd.concat([dust201701, dust201702])
temp = pd.concat([temp, dust201703])
temp = pd.concat([temp, dust201704])

# %%
temp['시간'] = temp['측정일시'].astype(str).str.slice(8,10,1)
temp['날짜'] = temp['측정일시'].astype(str).str.slice(0,8,1)
temp.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1     지역 측정소명        측정일시  미세먼지  초미세먼지           주소  \
# 0      384480        384480  광주 동구  서석동  2017010101  35.0   23.0  광주 동구 서남로 1
# 1      384481        384481  광주 동구  서석동  2017010102  34.0   23.0  광주 동구 서남로 1
# 2      384482        384482  광주 동구  서석동  2017010103  28.0   20.0  광주 동구 서남로 1
# 3      384483        384483  광주 동구  서석동  2017010104  28.0   19.0  광주 동구 서남로 1
# 4      384484        384484  광주 동구  서석동  2017010105  25.0   20.0  광주 동구 서남로 1
#
#    시간        날짜
# 0  01  20170101
# 1  02  20170101
# 2  03  20170101
# 3  04  20170101
# 4  05  20170101

# %%
del temp['Unnamed: 0']
del temp['Unnamed: 0.1']
del temp['측정일시']

# %%
east = temp[temp['지역'] == '광주 동구']
west = temp[temp['지역'] == '광주 서구']
south = temp[temp['지역'] == '광주 남구']
north = temp[temp['지역'] == '광주 북구']
mid = temp[temp['지역'] == '광주 광산구']
west_nong = west[west['측정소명'] == '농성동']
west_chi = west[west['측정소명'] == '치평동']
north_dooam = north[north['측정소명'] == '두암동']
north_unnam = north[north['측정소명'] == '운암동']
north_kunkuk = north[north['측정소명'] == '건국동']
mid_songjeong = mid[mid['측정소명'] == '송정1동']
mid_oseon = mid[mid['측정소명'] == '오선동']

# %%
east = east[east['시간'] == '14']
south = south[south['시간'] == '14']
west_nong = west_nong[west_nong['시간'] == '14']
west_chi = west_chi[west_chi['시간'] == '14']
north_dooam = north_dooam[north_dooam['시간'] == '14']
north_unnam = north_unnam[north_unnam['시간'] == '14']
north_kunkuk = north_kunkuk[north_kunkuk['시간'] == '14']
mid_songjeong = mid_songjeong[mid_songjeong['시간'] == '14']
mid_oseon = mid_oseon[mid_oseon['시간'] == '14']

# %%
east.to_csv('../dust2017/east2017.csv', encoding='euc-kr')
south.to_csv('../dust2017/south2017.csv', encoding='euc-kr')
west_nong.to_csv('../dust2017/west_nong2017.csv', encoding='euc-kr')
west_chi.to_csv('../dust2017/west_chi2017.csv', encoding='euc-kr')
north_dooam.to_csv('../dust2017/north_dooam2017.csv', encoding='euc-kr')
north_unnam.to_csv('../dust2017/north_unnam2017.csv', encoding='euc-kr')
north_kunkuk.to_csv('../dust2017/north_kunkuk2017.csv', encoding='euc-kr')
mid_songjeong.to_csv('../dust2017/mid_songjeong2017.csv', encoding='euc-kr')
mid_oseon.to_csv('../dust2017/mid_oseon2017.csv', encoding='euc-kr')
